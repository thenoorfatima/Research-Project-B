# %%
from PIL import Image
import numpy as np
import cv2
import os

# %%
root = "D:/College Work/Internship/AMU CSS/Dataset/dataset-resized/"

# %%
files_papaya = []
# r=root, d=directories, f = files
for r, d, f in os.walk(root + "papaya"):
    for file in f:
        files_papaya.append(file)
files_papaya.sort(key=lambda f: int(''.join(filter(str.isdigit, f))))

# %%
X = []
Y = []
for image in files_papaya[0:500]:
    img = Image.open(root + 'papaya/' + image)
    img.load()
    data = np.asarray(img)
    data = cv2.cvtColor(data, cv2.COLOR_BGRA2BGR)
    X.append(data)
    Y.append(0)

# %%
files_pepper = []
# r=root, d=directories, f = files
for r, d, f in os.walk(root + "pepper"):
    for file in f:
        files_pepper.append(file)
files_pepper.sort(key=lambda f: int(''.join(filter(str.isdigit, f))))

# %%
for image in files_pepper[0:500]:
    img = Image.open(root + 'pepper/' + image)
    img.load()
    data = np.asarray(img)
    data = cv2.cvtColor(data, cv2.COLOR_BGRA2BGR)
    X.append(data)
    Y.append(1)

# %%
X = np.array(X)
Y = np.array(Y)

# %%
print(X.shape, Y.shape)
# Out:
# (1000, 400, 400, 3) (1000,)

# %%
from skimage.io import imshow
import matplotlib.pyplot as plt

idx = int(np.random.rand(1,1)*1000)
idx = 700
imshow(np.squeeze(X[idx,:,:,:]))
plt.show()

labels = ['Papaya','Pepper']
print ('This is:',labels[int(Y[idx])])
# Out:
# This is: Pepper

# %%
from tensorflow.keras.utils import to_categorical
from keras.utils import np_utils
Y = np_utils.to_categorical(Y)

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, Y_train, Y_test = train_test_split(X,Y, test_size = 0.10, random_state=42)

# %%
from skimage.io import imshow
import matplotlib.pyplot as plt

idx = int(np.random.rand(1,1)*900)

imshow(np.squeeze(X_train[idx,:,:,:]))
plt.show()

print("Index is:", idx)
labels = ['Papaya','Pepper']
print ('This is:',labels[int(np.argmax(Y_train[idx], axis=0))])
# Out:
# Index is: 31
# This is: Pepper

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D, Activation, MaxPooling2D, Conv2D, Flatten, Dense
import keras
import tensorflow as tf

model = Sequential()
model.add(Conv2D(input_shape=(400,400,3), filters=6, kernel_size=5, strides=1, padding="same"))
model.add(Activation('relu'))
model.add(MaxPooling2D(pool_size=(4)))
model.add(Conv2D(16, kernel_size=5, strides=1, padding="same"))
model.add(Activation('relu'))
model.add(MaxPooling2D(pool_size=(4)))
model.add(Flatten())
model.add(Dense(2))
model.add(Activation('softmax'))

# %%
model.compile(loss="categorical_crossentropy",
              optimizer='adam',
              metrics=['accuracy'])

# %%
verbose = 1
cnnhistory=model.fit(X_train, Y_train, epochs=100, verbose=verbose, validation_data=(X_test, Y_test))
_, accuracy = model.evaluate(X_test, Y_test, verbose=verbose)
# Out:
# Epoch 1/100
# 29/29 [==============================] - 4s 68ms/step - loss: 43.0051 - accuracy: 0.5922 - val_loss: 1.8476 - val_accuracy: 0.6000
# Epoch 2/100
# 29/29 [==============================] - 2s 59ms/step - loss: 1.0549 - accuracy: 0.6311 - val_loss: 0.7980 - val_accuracy: 0.6700
# Epoch 3/100
# 29/29 [==============================] - 2s 59ms/step - loss: 0.6636 - accuracy: 0.7200 - val_loss: 0.5264 - val_accuracy: 0.7600
# Epoch 4/100
# 29/29 [==============================] - 2s 59ms/step - loss: 0.4748 - accuracy: 0.8067 - val_loss: 0.4888 - val_accuracy: 0.7700
# Epoch 5/100
# 29/29 [==============================] - 2s 59ms/step - loss: 0.3779 - accuracy: 0.8433 - val_loss: 0.4938 - val_accuracy: 0.8300
# Epoch 6/100
# 29/29 [==============================] - 2s 61ms/step - loss: 0.2831 - accuracy: 0.8833 - val_loss: 0.3754 - val_accuracy: 0.8500
# Epoch 7/100
# 29/29 [==============================] - 2s 60ms/step - loss: 0.2136 - accuracy: 0.9089 - val_loss: 0.4135 - val_accuracy: 0.8400
# Epoch 8/100
# 29/29 [==============================] - 2s 60ms/step - loss: 0.1874 - accuracy: 0.9233 - val_loss: 0.2689 - val_accuracy: 0.9400
# Epoch 9/100
# 29/29 [==============================] - 2s 60ms/step - loss: 0.1359 - accuracy: 0.9467 - val_loss: 0.2653 - val_accuracy: 0.8900
# Epoch 10/100
# 29/29 [==============================] - 2s 60ms/step - loss: 0.1117 - accuracy: 0.9611 - val_loss: 0.3018 - val_accuracy: 0.9000
# Epoch 11/100
# 29/29 [==============================] - 2s 61ms/step - loss: 0.0935 - accuracy: 0.9689 - val_loss: 0.2342 - val_accuracy: 0.9100
# Epoch 12/100
# 29/29 [==============================] - 2s 60ms/step - loss: 0.0892 - accuracy: 0.9689 - val_loss: 0.2671 - val_accuracy: 0.9100
# Epoch 13/100
# 29/29 [==============================] - 2s 59ms/step - loss: 0.1409 - accuracy: 0.9400 - val_loss: 0.3377 - val_accuracy: 0.8800
# Epoch 14/100
# 29/29 [==============================] - 2s 59ms/step - loss: 0.0816 - accuracy: 0.9689 - val_loss: 0.1886 - val_accuracy: 0.9200
# Epoch 15/100
# 29/29 [==============================] - 2s 59ms/step - loss: 0.0623 - accuracy: 0.9811 - val_loss: 0.3262 - val_accuracy: 0.9100
# Epoch 16/100
# 29/29 [==============================] - 2s 59ms/step - loss: 0.0472 - accuracy: 0.9878 - val_loss: 0.2607 - val_accuracy: 0.9100
# Epoch 17/100
# 29/29 [==============================] - 2s 59ms/step - loss: 0.0694 - accuracy: 0.9767 - val_loss: 0.3132 - val_accuracy: 0.9000
# Epoch 18/100
# 29/29 [==============================] - 2s 59ms/step - loss: 0.0493 - accuracy: 0.9789 - val_loss: 0.4178 - val_accuracy: 0.8900
# Epoch 19/100
# 29/29 [==============================] - 2s 59ms/step - loss: 0.0342 - accuracy: 0.9911 - val_loss: 0.2846 - val_accuracy: 0.9000
# Epoch 20/100
# 29/29 [==============================] - 2s 59ms/step - loss: 0.0304 - accuracy: 0.9889 - val_loss: 0.2563 - val_accuracy: 0.9100
# Epoch 21/100
# 29/29 [==============================] - 2s 59ms/step - loss: 0.0207 - accuracy: 0.9933 - val_loss: 0.2683 - val_accuracy: 0.9000
# Epoch 22/100
# 29/29 [==============================] - 2s 59ms/step - loss: 0.0159 - accuracy: 0.9989 - val_loss: 0.2764 - val_accuracy: 0.9000
# Epoch 23/100
# 29/29 [==============================] - 2s 59ms/step - loss: 0.0119 - accuracy: 0.9978 - val_loss: 0.2907 - val_accuracy: 0.9100
# Epoch 24/100
# 29/29 [==============================] - 2s 59ms/step - loss: 0.0104 - accuracy: 0.9989 - val_loss: 0.3517 - val_accuracy: 0.8900
# Epoch 25/100
# 29/29 [==============================] - 2s 64ms/step - loss: 0.0167 - accuracy: 0.9978 - val_loss: 0.3208 - val_accuracy: 0.9200
# Epoch 26/100
# 29/29 [==============================] - 2s 59ms/step - loss: 0.0077 - accuracy: 1.0000 - val_loss: 0.3811 - val_accuracy: 0.9000
# Epoch 27/100
# 29/29 [==============================] - 2s 60ms/step - loss: 0.0043 - accuracy: 1.0000 - val_loss: 0.3885 - val_accuracy: 0.8900
# Epoch 28/100
# 29/29 [==============================] - 2s 60ms/step - loss: 0.0034 - accuracy: 1.0000 - val_loss: 0.4667 - val_accuracy: 0.8700
# Epoch 29/100
# 29/29 [==============================] - 2s 59ms/step - loss: 0.0028 - accuracy: 1.0000 - val_loss: 0.4113 - val_accuracy: 0.9100
# Epoch 30/100
# 29/29 [==============================] - 2s 59ms/step - loss: 0.0019 - accuracy: 1.0000 - val_loss: 0.4138 - val_accuracy: 0.9000
# Epoch 31/100
# 29/29 [==============================] - 2s 59ms/step - loss: 0.0016 - accuracy: 1.0000 - val_loss: 0.4202 - val_accuracy: 0.9100
# Epoch 32/100
# 29/29 [==============================] - 2s 59ms/step - loss: 0.0014 - accuracy: 1.0000 - val_loss: 0.4180 - val_accuracy: 0.9100
# Epoch 33/100
# 29/29 [==============================] - 2s 59ms/step - loss: 0.0012 - accuracy: 1.0000 - val_loss: 0.4421 - val_accuracy: 0.9000
# Epoch 34/100
# 29/29 [==============================] - 2s 59ms/step - loss: 0.0011 - accuracy: 1.0000 - val_loss: 0.4536 - val_accuracy: 0.9000
# Epoch 35/100
# 29/29 [==============================] - 2s 59ms/step - loss: 9.3391e-04 - accuracy: 1.0000 - val_loss: 0.4303 - val_accuracy: 0.9100
# Epoch 36/100
# 29/29 [==============================] - 2s 59ms/step - loss: 8.3742e-04 - accuracy: 1.0000 - val_loss: 0.4308 - val_accuracy: 0.9100
# Epoch 37/100
# 29/29 [==============================] - 2s 59ms/step - loss: 7.6443e-04 - accuracy: 1.0000 - val_loss: 0.4394 - val_accuracy: 0.9000
# Epoch 38/100
# 29/29 [==============================] - 2s 59ms/step - loss: 6.9916e-04 - accuracy: 1.0000 - val_loss: 0.4367 - val_accuracy: 0.9100
# Epoch 39/100
# 29/29 [==============================] - 2s 59ms/step - loss: 6.3397e-04 - accuracy: 1.0000 - val_loss: 0.4404 - val_accuracy: 0.9100
# Epoch 40/100
# 29/29 [==============================] - 2s 59ms/step - loss: 5.8417e-04 - accuracy: 1.0000 - val_loss: 0.4498 - val_accuracy: 0.9100
# Epoch 41/100
# 29/29 [==============================] - 2s 59ms/step - loss: 5.2832e-04 - accuracy: 1.0000 - val_loss: 0.4424 - val_accuracy: 0.9100
# Epoch 42/100
# 29/29 [==============================] - 2s 59ms/step - loss: 5.0831e-04 - accuracy: 1.0000 - val_loss: 0.4493 - val_accuracy: 0.9100
# Epoch 43/100
# 29/29 [==============================] - 2s 59ms/step - loss: 4.8237e-04 - accuracy: 1.0000 - val_loss: 0.4536 - val_accuracy: 0.9100
# Epoch 44/100
# 29/29 [==============================] - 2s 59ms/step - loss: 4.2718e-04 - accuracy: 1.0000 - val_loss: 0.4487 - val_accuracy: 0.9100
# Epoch 45/100
# 29/29 [==============================] - 2s 59ms/step - loss: 4.2382e-04 - accuracy: 1.0000 - val_loss: 0.4675 - val_accuracy: 0.9100
# Epoch 46/100
# 29/29 [==============================] - 2s 59ms/step - loss: 3.9082e-04 - accuracy: 1.0000 - val_loss: 0.4727 - val_accuracy: 0.9100
# Epoch 47/100
# 29/29 [==============================] - 2s 59ms/step - loss: 3.6823e-04 - accuracy: 1.0000 - val_loss: 0.4684 - val_accuracy: 0.9100
# Epoch 48/100
# 29/29 [==============================] - 2s 59ms/step - loss: 3.3412e-04 - accuracy: 1.0000 - val_loss: 0.4612 - val_accuracy: 0.9100
# Epoch 49/100
# 29/29 [==============================] - 2s 59ms/step - loss: 3.3576e-04 - accuracy: 1.0000 - val_loss: 0.4670 - val_accuracy: 0.9100
# Epoch 50/100
# 29/29 [==============================] - 2s 59ms/step - loss: 3.6430e-04 - accuracy: 1.0000 - val_loss: 0.4661 - val_accuracy: 0.9100
# Epoch 51/100
# 29/29 [==============================] - 2s 59ms/step - loss: 2.8894e-04 - accuracy: 1.0000 - val_loss: 0.4683 - val_accuracy: 0.9100
# Epoch 52/100
# 29/29 [==============================] - 2s 59ms/step - loss: 2.7414e-04 - accuracy: 1.0000 - val_loss: 0.4739 - val_accuracy: 0.9100
# Epoch 53/100
# 29/29 [==============================] - 2s 59ms/step - loss: 2.5576e-04 - accuracy: 1.0000 - val_loss: 0.4726 - val_accuracy: 0.9100
# Epoch 54/100
# 29/29 [==============================] - 2s 59ms/step - loss: 2.5046e-04 - accuracy: 1.0000 - val_loss: 0.4777 - val_accuracy: 0.9100
# Epoch 55/100
# 29/29 [==============================] - 2s 59ms/step - loss: 2.3329e-04 - accuracy: 1.0000 - val_loss: 0.4860 - val_accuracy: 0.9100
# Epoch 56/100
# 29/29 [==============================] - 2s 59ms/step - loss: 2.2804e-04 - accuracy: 1.0000 - val_loss: 0.4783 - val_accuracy: 0.9100
# Epoch 57/100
# 29/29 [==============================] - 2s 59ms/step - loss: 2.1770e-04 - accuracy: 1.0000 - val_loss: 0.4895 - val_accuracy: 0.9100
# Epoch 58/100
# 29/29 [==============================] - 2s 59ms/step - loss: 2.0609e-04 - accuracy: 1.0000 - val_loss: 0.4847 - val_accuracy: 0.9100
# Epoch 59/100
# 29/29 [==============================] - 2s 60ms/step - loss: 1.9800e-04 - accuracy: 1.0000 - val_loss: 0.4874 - val_accuracy: 0.9100
# Epoch 60/100
# 29/29 [==============================] - 2s 59ms/step - loss: 1.9037e-04 - accuracy: 1.0000 - val_loss: 0.4928 - val_accuracy: 0.9100
# Epoch 61/100
# 29/29 [==============================] - 2s 59ms/step - loss: 1.8224e-04 - accuracy: 1.0000 - val_loss: 0.4911 - val_accuracy: 0.9100
# Epoch 62/100
# 29/29 [==============================] - 2s 59ms/step - loss: 1.7535e-04 - accuracy: 1.0000 - val_loss: 0.4945 - val_accuracy: 0.9100
# Epoch 63/100
# 29/29 [==============================] - 2s 59ms/step - loss: 1.7714e-04 - accuracy: 1.0000 - val_loss: 0.5008 - val_accuracy: 0.9100
# Epoch 64/100
# 29/29 [==============================] - 2s 59ms/step - loss: 1.6691e-04 - accuracy: 1.0000 - val_loss: 0.5014 - val_accuracy: 0.9100
# Epoch 65/100
# 29/29 [==============================] - 2s 59ms/step - loss: 1.5692e-04 - accuracy: 1.0000 - val_loss: 0.5016 - val_accuracy: 0.9100
# Epoch 66/100
# 29/29 [==============================] - 2s 60ms/step - loss: 1.5333e-04 - accuracy: 1.0000 - val_loss: 0.5017 - val_accuracy: 0.9100
# Epoch 67/100
# 29/29 [==============================] - 2s 59ms/step - loss: 1.4569e-04 - accuracy: 1.0000 - val_loss: 0.5038 - val_accuracy: 0.9100
# Epoch 68/100
# 29/29 [==============================] - 2s 59ms/step - loss: 1.4116e-04 - accuracy: 1.0000 - val_loss: 0.5085 - val_accuracy: 0.9100
# Epoch 69/100
# 29/29 [==============================] - 2s 59ms/step - loss: 1.3605e-04 - accuracy: 1.0000 - val_loss: 0.5028 - val_accuracy: 0.9100
# Epoch 70/100
# 29/29 [==============================] - 2s 59ms/step - loss: 1.3057e-04 - accuracy: 1.0000 - val_loss: 0.5090 - val_accuracy: 0.9100
# Epoch 71/100
# 29/29 [==============================] - 2s 59ms/step - loss: 1.2733e-04 - accuracy: 1.0000 - val_loss: 0.5059 - val_accuracy: 0.9100
# Epoch 72/100
# 29/29 [==============================] - 2s 59ms/step - loss: 1.2267e-04 - accuracy: 1.0000 - val_loss: 0.5168 - val_accuracy: 0.9100
# Epoch 73/100
# 29/29 [==============================] - 2s 59ms/step - loss: 1.1702e-04 - accuracy: 1.0000 - val_loss: 0.5112 - val_accuracy: 0.9100
# Epoch 74/100
# 29/29 [==============================] - 2s 59ms/step - loss: 1.1472e-04 - accuracy: 1.0000 - val_loss: 0.5114 - val_accuracy: 0.9100
# Epoch 75/100
# 29/29 [==============================] - 2s 59ms/step - loss: 1.0956e-04 - accuracy: 1.0000 - val_loss: 0.5120 - val_accuracy: 0.9100
# Epoch 76/100
# 29/29 [==============================] - 2s 59ms/step - loss: 1.1327e-04 - accuracy: 1.0000 - val_loss: 0.5190 - val_accuracy: 0.9100
# Epoch 77/100
# 29/29 [==============================] - 2s 59ms/step - loss: 1.0836e-04 - accuracy: 1.0000 - val_loss: 0.5229 - val_accuracy: 0.9100
# Epoch 78/100
# 29/29 [==============================] - 2s 59ms/step - loss: 9.8830e-05 - accuracy: 1.0000 - val_loss: 0.5147 - val_accuracy: 0.9100
# Epoch 79/100
# 29/29 [==============================] - 2s 60ms/step - loss: 9.5519e-05 - accuracy: 1.0000 - val_loss: 0.5213 - val_accuracy: 0.9100
# Epoch 80/100
# 29/29 [==============================] - 2s 59ms/step - loss: 9.4016e-05 - accuracy: 1.0000 - val_loss: 0.5080 - val_accuracy: 0.9100
# Epoch 81/100
# 29/29 [==============================] - 2s 59ms/step - loss: 9.0850e-05 - accuracy: 1.0000 - val_loss: 0.5078 - val_accuracy: 0.9100
# Epoch 82/100
# 29/29 [==============================] - 2s 59ms/step - loss: 8.7298e-05 - accuracy: 1.0000 - val_loss: 0.5136 - val_accuracy: 0.9100
# Epoch 83/100
# 29/29 [==============================] - 2s 60ms/step - loss: 8.4051e-05 - accuracy: 1.0000 - val_loss: 0.5169 - val_accuracy: 0.9100
# Epoch 84/100
# 29/29 [==============================] - 2s 59ms/step - loss: 8.2985e-05 - accuracy: 1.0000 - val_loss: 0.5197 - val_accuracy: 0.9100
# Epoch 85/100
# 29/29 [==============================] - 2s 59ms/step - loss: 7.9402e-05 - accuracy: 1.0000 - val_loss: 0.5260 - val_accuracy: 0.9100
# Epoch 86/100
# 29/29 [==============================] - 2s 59ms/step - loss: 7.7265e-05 - accuracy: 1.0000 - val_loss: 0.5223 - val_accuracy: 0.9100
# Epoch 87/100
# 29/29 [==============================] - 2s 60ms/step - loss: 7.4893e-05 - accuracy: 1.0000 - val_loss: 0.5233 - val_accuracy: 0.9100
# Epoch 88/100
# 29/29 [==============================] - 2s 59ms/step - loss: 7.3343e-05 - accuracy: 1.0000 - val_loss: 0.5322 - val_accuracy: 0.9100
# Epoch 89/100
# 29/29 [==============================] - 2s 59ms/step - loss: 7.1666e-05 - accuracy: 1.0000 - val_loss: 0.5289 - val_accuracy: 0.9100
# Epoch 90/100
# 29/29 [==============================] - 2s 59ms/step - loss: 6.7595e-05 - accuracy: 1.0000 - val_loss: 0.5265 - val_accuracy: 0.9100
# Epoch 91/100
# 29/29 [==============================] - 2s 59ms/step - loss: 6.6013e-05 - accuracy: 1.0000 - val_loss: 0.5283 - val_accuracy: 0.9100
# Epoch 92/100
# 29/29 [==============================] - 2s 61ms/step - loss: 6.4707e-05 - accuracy: 1.0000 - val_loss: 0.5326 - val_accuracy: 0.9100
# Epoch 93/100
# 29/29 [==============================] - 2s 63ms/step - loss: 6.3838e-05 - accuracy: 1.0000 - val_loss: 0.5337 - val_accuracy: 0.9100
# Epoch 94/100
# 29/29 [==============================] - 2s 62ms/step - loss: 6.2547e-05 - accuracy: 1.0000 - val_loss: 0.5389 - val_accuracy: 0.9100
# Epoch 95/100
# 29/29 [==============================] - 2s 62ms/step - loss: 5.9820e-05 - accuracy: 1.0000 - val_loss: 0.5425 - val_accuracy: 0.9100
# Epoch 96/100
# 29/29 [==============================] - 2s 62ms/step - loss: 5.7907e-05 - accuracy: 1.0000 - val_loss: 0.5334 - val_accuracy: 0.9100
# Epoch 97/100
# 29/29 [==============================] - 2s 61ms/step - loss: 5.6781e-05 - accuracy: 1.0000 - val_loss: 0.5342 - val_accuracy: 0.9100
# Epoch 98/100
# 29/29 [==============================] - 2s 60ms/step - loss: 5.4498e-05 - accuracy: 1.0000 - val_loss: 0.5276 - val_accuracy: 0.9100
# Epoch 99/100
# 29/29 [==============================] - 2s 61ms/step - loss: 5.3443e-05 - accuracy: 1.0000 - val_loss: 0.5294 - val_accuracy: 0.9100
# Epoch 100/100
# 29/29 [==============================] - 2s 62ms/step - loss: 5.3431e-05 - accuracy: 1.0000 - val_loss: 0.5357 - val_accuracy: 0.9100
# 4/4 [==============================] - 0s 21ms/step - loss: 0.5357 - accuracy: 0.9100

# %%
model.save("Models/cnn_adam_100_tr=100_te=91_random-42")
# Out:
# INFO:tensorflow:Assets written to: Models/cnn_adam_100_tr=100_te=91_random-42\assets
